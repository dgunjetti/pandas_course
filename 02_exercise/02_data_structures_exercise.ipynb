# %% [markdown]
# # Series

# %% [markdown]
# ## Data Analysis before starting Onion Farming Business

# %%
from IPython.display import Image, display
image_path = '../images/abhishek-hajare-D9h2-RxM1rE-unsplash.jpg'
display(Image(filename=image_path, width=300, height=200))

# %%
import numpy as np
import pandas as pd

# %%
onion_prices = [32.0, 36.0, 24.0, 22.0, 18.0, 24.0, 22.0, 24.0, 24.0, 34.0, 32.0, 30.0]

# %% [markdown]
# ### Task 1a: Create a Series from List

# %% [markdown]
# ### Task 1b: Create a Series and Set Index

# %%
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", 
          "October", "November", "December"]

# %% [markdown]
# ### Task 1c: Create a Series from dictionary

# %%
onion_price_by_month = {
    "January": 32.0,
    "February": 36.0,
    "March": 24.0,
    "April": 22.0,
    "May": 18.0,
    "June": 24.0,
    "July": 22.0,
    "August": 24.0,
    "September": 24.0,
    "October": 34.0,
    "November": 32.0,
    "December": 30.0
}

# %% [markdown]
# ### Task 1d: Get price value for particular month.

# %% [markdown]
# ### Task 2: When to harvest onion to get better price.

# %% [markdown]
# ### Task 2a: Get months when onions price are lowest.

# %% [markdown]
# ### Task 3: Get onion price after export duty.

# %%
export_duty = {
    "December": 5.0,
    "November": 5.0,
    "October": 5.0,
    "September": 5.0,
    "August": 40.0,
    "July": 40.0,
    "June": 40.0,
    "May": 40.0,
    "April": 25.0,
    "March": 25.0,
    "February": 25.0,
    "January": 25.0
}
export_duty_s = pd.Series(export_duty)
export_duty_s
# Out:
# December      5.0
# November      5.0
# October       5.0
# September     5.0
# August       40.0
# July         40.0
# June         40.0
# May          40.0
# April        25.0
# March        25.0
# February     25.0
# January      25.0
# dtype: float64

# %% [markdown]
# #### Data aligned to index label

# %% [markdown]
# # DataFrames

# %% [markdown]
# ## Analyze Coffee Shop Business

# %%
image_path = '../images/nafinia-putra-Kwdp-0pok-I-unsplash.jpg'
display(Image(filename=image_path))

# %%
coffee_store_1 = [ 
        {"date": "2023-11-06",
         "tea": 100,
         "coffee":153,
         "bread": 30,
         "pastry" : 40}, 
        {"date": "2023-11-07",
         "tea": 108,
         "coffee":163,
         "bread": 28,
         "pastry" : 35},  
        {"date": "2023-11-08",
         "tea": 103,
         "coffee":130,
         "bread": 39,
         "pastry" : 42}, 
        {"date": "2023-11-09",
         "tea": 104,
         "coffee":150,
         "bread": 32,
         "pastry" : 44}, 
        {"date": "2023-11-10",
         "tea": 89,
         "coffee":180,
         "bread": 35,
         "pastry" : 42}, 
        {"date": "2023-11-11",
         "tea": 50,
         "coffee":75,
         "bread": 100,
         "pastry" : 140}, 
        {"date": "2023-11-12",
         "tea": 45,
         "coffee": 50,
         "bread": 130,
         "pastry" : 185}, 
]

# %% [markdown]
# ### Task 1a: Create DataFrame for Dictionary

# %% [markdown]
# ### Task 1b: Convert column with string date values to pandas datetime objects.

# %% [markdown]
# ### Task 2a: Create columns for category beverages and bakery.

# %% [markdown]
# ### Task 2b: Get which category of items are sold most on week days and week ends.
